# %% [markdown]
# # Inpainting
# - **random** sampling
# - probability **50%**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/inpainting/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/inpainting/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/inpainting/plain" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "test" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/inpainting/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/inpainting/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/inpainting/residual" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"
# Out:
# mode: test
# learning rate: 1.0000e-03
# batch size: 4
# number of epoch: 100
# task: inpainting
# opts: ['random', array([0.5])]
# network: unet
# learning type: residual
# data dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images
# ckpt dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/inpainting/residual
# log dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/inpainting/residual
# result dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/inpainting/residual
# device: cuda
# 2020-04-03 03:25:34.776639: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# TEST: BATCH 0001 / 0050 | LOSS 0.0028
# TEST: BATCH 0002 / 0050 | LOSS 0.0045
# TEST: BATCH 0003 / 0050 | LOSS 0.0039
# TEST: BATCH 0004 / 0050 | LOSS 0.0034
# ...

# %% [markdown]
# # Denoising
# - **random** noise
# - sigma **30.0**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/denoising/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/denoising/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/denoising/plain" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/denoising/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/denoising/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/denoising/residual" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/super_resolution/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/super_resolution/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/super_resolution/plain" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/checkpoint/super_resolution/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/log/super_resolution/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-image-regression-framework/result/super_resolution/residual" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"
