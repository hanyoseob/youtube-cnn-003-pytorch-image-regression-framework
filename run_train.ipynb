# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/inpainting/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/inpainting/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/inpainting/plain" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"
# Out:
# Streaming output truncated to the last 5000 lines.
# TRAIN: EPOCH 0034 / 0100 | BATCH 0027 / 0050 | LOSS 0.0194
# TRAIN: EPOCH 0034 / 0100 | BATCH 0028 / 0050 | LOSS 0.0189
# TRAIN: EPOCH 0034 / 0100 | BATCH 0029 / 0050 | LOSS 0.0189
# TRAIN: EPOCH 0034 / 0100 | BATCH 0030 / 0050 | LOSS 0.0189
# TRAIN: EPOCH 0034 / 0100 | BATCH 0031 / 0050 | LOSS 0.0191
# TRAIN: EPOCH 0034 / 0100 | BATCH 0032 / 0050 | LOSS 0.0194
# TRAIN: EPOCH 0034 / 0100 | BATCH 0033 / 0050 | LOSS 0.0192
# TRAIN: EPOCH 0034 / 0100 | BATCH 0034 / 0050 | LOSS 0.0196
# TRAIN: EPOCH 0034 / 0100 | BATCH 0035 / 0050 | LOSS 0.0195
# TRAIN: EPOCH 0034 / 0100 | BATCH 0036 / 0050 | LOSS 0.0196
# TRAIN: EPOCH 0034 / 0100 | BATCH 0037 / 0050 | LOSS 0.0193
# TRAIN: EPOCH 0034 / 0100 | BATCH 0038 / 0050 | LOSS 0.0192
# TRAIN: EPOCH 0034 / 0100 | BATCH 0039 / 0050 | LOSS 0.0193
# TRAIN: EPOCH 0034 / 0100 | BATCH 0040 / 0050 | LOSS 0.0195
# TRAIN: EPOCH 0034 / 0100 | BATCH 0041 / 0050 | LOSS 0.0199
# ...

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/inpainting/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/inpainting/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/inpainting/residual" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/denoising/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/denoising/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/denoising/plain" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/denoising/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/denoising/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/denoising/residual" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/super_resolution_ds2/plain" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/super_resolution_ds2/plain" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/super_resolution_ds2/plain" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 2.0 \
--learning_type "plain"
# Out:
# Streaming output truncated to the last 5000 lines.
# TRAIN: EPOCH 0034 / 0100 | BATCH 0027 / 0050 | LOSS 0.0225
# TRAIN: EPOCH 0034 / 0100 | BATCH 0028 / 0050 | LOSS 0.0221
# TRAIN: EPOCH 0034 / 0100 | BATCH 0029 / 0050 | LOSS 0.0228
# TRAIN: EPOCH 0034 / 0100 | BATCH 0030 / 0050 | LOSS 0.0226
# TRAIN: EPOCH 0034 / 0100 | BATCH 0031 / 0050 | LOSS 0.0223
# TRAIN: EPOCH 0034 / 0100 | BATCH 0032 / 0050 | LOSS 0.0224
# TRAIN: EPOCH 0034 / 0100 | BATCH 0033 / 0050 | LOSS 0.0221
# TRAIN: EPOCH 0034 / 0100 | BATCH 0034 / 0050 | LOSS 0.0218
# TRAIN: EPOCH 0034 / 0100 | BATCH 0035 / 0050 | LOSS 0.0219
# TRAIN: EPOCH 0034 / 0100 | BATCH 0036 / 0050 | LOSS 0.0217
# TRAIN: EPOCH 0034 / 0100 | BATCH 0037 / 0050 | LOSS 0.0215
# TRAIN: EPOCH 0034 / 0100 | BATCH 0038 / 0050 | LOSS 0.0213
# TRAIN: EPOCH 0034 / 0100 | BATCH 0039 / 0050 | LOSS 0.0212
# TRAIN: EPOCH 0034 / 0100 | BATCH 0040 / 0050 | LOSS 0.0212
# TRAIN: EPOCH 0034 / 0100 | BATCH 0041 / 0050 | LOSS 0.0210
# ...

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/super_resolution_ds2/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/super_resolution_ds2/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/super_resolution_ds2/residual" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 2.0 \
--learning_type "residual"
# Out:
# learning rate: 1.0000e-03
# batch size: 4
# number of epoch: 100
# data dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/datasets/BSR/BSDS500/data/images
# ckpt dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/checkpoint/super_resolution_ds2/residual
# log dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/log/super_resolution_ds2/residual
# result dir: /content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/result/super_resolution_ds2/residual
# task: super_resolution
# opts: ['bilinear', array([2.])]
# network: unet
# learning type: residual
# mode: train
# device: cuda
# Traceback (most recent call last):
#   File "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-regression/train.py", line 137, in <module>
#     net = UNet(nch=nch, nker=nker, learning_type=learning_type).to(device)
# ...
